# %% [markdown]
# ##Theory Questions

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# Ans. Hypothesis testing in statistics is a method used to make decisions or inferences about a population based on sample data. It helps determine whether there is enough evidence to support a specific belief or claim about a population parameter.
#
# **Basic Idea:**
# You start with **two competing hypotheses:**
#
# * **Null Hypothesis:** This is the default or initial assumption. It usually states that there is no effect, no difference or no relationship.
#
# * **Alternative Hypothesis:** This is what you want to test for- it suggests thta there is an effect, a difference or a relationship.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# Ans. **Null Hypothesis** is the starting assumption in hypothesis testing . It claims that there is no effect, no difference or no relationship in the population. It's what you are trying to test against.
#
# * It is typically a statement of "no change" or status quo.
# * It is assumed to be true until there is strong evidence against it.
#
# **Alternative Hypothesis** is what you **want to prove or find evidence for.**It suggests that there is an effect, a difference or  a relationship.
#
# * It represents a new claim or what you are testing to support.
# * If the data provide enough evidence, you reject ho in favor of H1.

# %% [markdown]
# 3. What is the significance level in hypothesis testing and whu is it important?
#
# Ans. The significance level, often denoted by α (alpha), is the threshold you set before testing to decide how much risk you're willing to take of rejecting the null hypothesis (H₀) when it's actually true. In other words, it's the probability of making a Type I error.
#
# **💡 In simple terms:**
# α = the cutoff for "how unlikely is unlikely enough"
#
# **Common values:**
#
# 0.05 → 5% chance of Type I error
#
# 0.01 → 1% chance
#
# 0.10 → 10% chance (less strict)
#
# **Why is it important?**
#
# Because it defines your level of confidence and controls how cautious you are when rejecting H₀. The lower the α:
#
# The stricter the test (harder to reject H₀)
#
# The lower the risk of claiming a false effect
#
# ⚖️ **It’s a trade-off:**
#
# Lower α → fewer false positives, but might miss a real effect (Type II error)
#
# Higher α → more sensitive to real effects, but riskier for false positives

# %% [markdown]
# 4. Why does a P-value represent in hypothesis testing?
#
# Ans.  **P-value:**	What it means
#
# * **High (e.g., 0.5)**:	The data is very likely under H₀ → don’t reject H₀
#
# * **Medium (e.g., 0.1)**:	Not very strong evidence → still don’t reject H₀
#
# * **Low (e.g., 0.03)**:	Unlikely under H₀ → reject H₀ if α = 0.05
#
# * **Very low (e.g., 0.001)**:	Strong evidence against H₀

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing?
#
# Ans. **The P-value** in hypothesis testing is a measure that helps determine the strength of the evidence against the null hypothesis. Here’s how to interpret it:
#
# * ** A small P-value (typically ≤ 0.05)** indicates strong evidence against the null hypothesis, meaning you may reject it in favor of the alternative hypothes
#
# **🧪 Example:**
#
# You're testing a new energy drink to see if it improves focus.
#
# H₀: The drink has no effect
#
# H₁: The drink improves focus
#
# You get a P-value = 0.03
#
# Your α = 0.05
#
# ✅ Since 0.03 < 0.05 → You reject H₀.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# Ans. **Type 1 Errore(False Positive):**
#
# * **Definition**: Rejecting the null hypothesis when it is actually **true**.
#
# * You are saying there is an effect or difference, but there are really isn't.
#
# * **Symbol:** The probabilty of a Type 1 error is alpha.
#
# * **Example:**
#    A COVID test says you are positive , but you are actually not infected.
#
# **Type 2 Error(False Neagtive):**
#
# * **Definition**: Failing to reject the null hypothesis when it is actually **false**.
#
# * **You are missing a real effect or difference.**
#
# * **Symbol**: The probabilty of Type 2 error is beta.
#
# * **Example:**
#    A pregnancy test says "not pregnant", but the person is pregnant.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# Ans. **🔹 One-tailed test**
#
# **Purpose:** Tests for an effect in one specific direction.
#
# **Example:** You're testing whether a new drug increases recovery rate compared to the current one.
#
# **Hypotheses:**
#
# **Null (H₀):** The drug has no effect or decreases recovery rate.
#
# **Alternative (H₁):** The drug increases recovery rate.
#
# **Used when:** You only care about a change in one direction (e.g., greater than, less than).
#
# **🔹 Two-tailed test**
#
# **Purpose:** Tests for an effect in either direction.
#
# **Example:** You're testing whether a new teaching method is different from the traditional one, regardless of whether it's better or worse.
#
# **Hypotheses:**
#
# **Null (H₀):** The new method has no effect.
#
# **Alternative (H₁):** The new method is different (could be better or worse).
#
# **Used when:** You care about any difference, not just an increase or decrease.
#
# **🔍 Visual analogy:**
#
# **One-tailed:** You're only looking on one side of the distribution.
#
# **Two-tailed:** You're looking on both sides.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# Ans. A **Z-test** is used when the test statistic follows a **normal distribution**, and it involves comparing the **Z-score (standard score)** of your sample statistic to a standard normal distribution (mean = 0, standard deviation = 1)
#
# **Types of Z-tests:**
#
# 1. **One-sample Z-test:**
#
# * Compares the **sample mean** to a known population mean.
#
# * Example: Is the average IQ score of a group different from the national average?
#
# 2. **Two-sample Z-test:**
#
# * Compares the means of **two independent samples**, assuming known **population variances.**
#
# * Example: Are the average test scores of students from two schools different?
#
# 3. **Z-test for proportions:**
#
# * Compares a **sample proportion** to a population proportion or compares **two sample proportions.**
#
# * Example: Is the proportion of left-handed students different between two classes?

# %% [markdown]
# 9. How do you calculate the Z-score and what does it represent in hypothesis testing?
#
# Ans.  How to calculate the Z-score
# The Z-score formula (for a sample mean) is:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# μ = population mean (under the null hypothesis)
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size

# %% [markdown]
# **In hypothesis testing:**
#
# 1. You calculate the **Z-score** for your sample.
#
# 2. You compare it to a **critical value** from the standard normal distribution (based on your significance level α):
#
#    *  For a two-tailed test at α = 0.05 → critical Z-values ≈ ±1.96
#
#    * For a one-tailed test at α = 0.05 → critical Z-value ≈ ±1.645
#
# 3. If the Z-score falls in the **critical region** (beyond those values), you **reject the null hypothesis.**

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# Ans. The **T-distribution** (also called Student's t-distribution) is a probability distribution that's **similar to the normal distribution**, but with **heavier tails.** These "fatter" tails mean there's a **greater chance of extreme values,** which makes it more accurate for small samples or when the population standard deviation is unknown.
#
# **How is it different from the normal distribution?**
#
# **Feature**                    **T-distribution**       **NormalDistribution**
#
# Shape                      Bell-shaped, heavier tails.    Bell-shaped
#
# Used when                  n is small                     n is large.
#
# Depends on                 **Degrees of freedom(df).**    doesn't depend on df
#
# Becomes normal when        it approaches normal           already normal.
#
# 1.   List item
# 2.   List item

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#
# Ans.**Z-Test**
#
# * **Use it When:**
#     * The population standard deviation is known.
#     * The sample size is large(typically n>30)
#
# * **Assumes**:
#    * Data is **normally distributed**(or approximately normal if the sample is large)
#    * **More precise** for large samples because the sampling distribution of the mean approximates normality.
#
# **T-Test**
#
# * **Use it when:**
#         * The population standard deviation is unknown.
#         * The sample size is typically small(n<=30)
#
# * **Uses the sample standard deviation(s)**
#
# * **Accounts for extra uncertainity** in small samples by using the **t-distribution**, which has fatter tails than the normal distribution.

# %% [markdown]
# 12. What is the T-test and how is it used in hypothesis testing?
#
# Ans. A **T-test** evaluates whether the means of two groups are statistically different from each other. It relies on the **t-distribution**, which is similar to the normal distribution but has heavier tails to account for extra variability in small samples.
#
# **How It's Used in Hypothesis Testing**
#
# 1. **Set Up Hypotheses**
#
# Null hypothesis (H₀): Assumes no difference or effect (e.g., the means are equal).
#
# Alternative hypothesis (H₁): Assumes a difference exists (e.g., the means are not equal).
#
# 2. **Choose the Right T-test**
#
# One-sample T-test: Compare a sample mean to a known value.
#
# Independent two-sample T-test: Compare means from two different groups.
#
# Paired sample T-test: Compare means from the same group at two different times (e.g., before and after treatment).
#
# 3. **Calculate the Test Statistic**
#
# The formula varies by test type, but generally:
#
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# t=
# s/
# n
# ​
#
# x
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#   = sample mean
#
# 𝜇
# μ = population mean (or second sample mean in two-sample case)
#
# 𝑠
# s = sample standard deviation
#
# 𝑛
# n = sample size
#
# 4. **Determine the Critical t-value**
#
# Based on:
#
# Degrees of freedom (df) = usually
# 𝑛
# −
# 1
# n−1
#
# Significance level (α) = commonly 0.05
#
# Use a t-table or software (like Python, Excel, SPSS) to find the critical value.
#
# 5. **Compare and Conclude**
#
# If
# ∣
# 𝑡
# ∣
# ∣t∣ > critical t-value → Reject H₀
#
# If
# ∣
# 𝑡
# ∣
# ∣t∣ ≤ critical t-value → Fail to reject H₀
#
# Or, use the p-value:
#
# If p ≤ α, reject H₀ (significant)
#
# If p > α, fail to reject H₀ (not significant)

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# Ans. The relationship between Z-test and T-test is given below as:
#
# **Z-Test**
# * **Purpose** : Test hypotheses about means
# * **Sample size**: Typically large(n>30)
# * **Distribution used**: **Standard normal distribution(Z)**
# * **When they converge**: For large samples
#
# **T-Test**
# * **Purpose** : Test hypotheses about means
# * **Sample size**: Typically small(n<=30)
# * **Distribution used**: **t-distribution(fatter tails)**
# * **When they converge**: T-distribution approaches normal as n increases.

# %% [markdown]
# 14. What is a confidence interval and how is it used to interpret statistical results?
#
# Ans. A **confidence interval** is a range constructed from sample data that likely contains the true population value. It's often reported alongside a **confidence level**, such as 95%.
#
# For example:
#
# **“The average test score is 78, with a 95% confidence interval of (74.2, 81.8).”**
#
# This means:
# We are **95% confident** that the true average test score (for the whole population) lies between **74.2 and 81.8.**
#
# **How It's Used in Interpreting Results**
#
# 1. **Estimation:** It gives a range instead of a single number (point estimate), which is more realistic.
#
# * Instead of saying, “The mean is 78,” you say, “It’s likely between 74.2 and 81.8.”
#
# 2. **Assessing Significance:**
#
# * If a 95% CI for a difference between means does NOT include 0, the result is statistically significant at the 5% level.
#
# * Example: CI = (2.3, 5.1) → there's likely a real difference between the two groups.
#
# 3. **Margin of Error:** The "±" part is often used in polling (e.g., “± 3%”), which comes directly from the confidence interval.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# Ans. The margin of error is the amount you add and subtract from a sample statistic (like the mean or proportion) to create a confidence interval.
#
# It represents the maximum expected difference between the true population value and the sample estimate, given a certain confidence level (like 95%).
#
# **Formula for Margin of Error**
#
# For a mean, the margin of error is:
#
# MoE
# =
# 𝑧
# ∗
# ⋅
# (
# 𝜎
# 𝑛
# )
# MoE=z
# ∗
#  ⋅(
# n
# ​
#
# σ
# ​
#  )
# or
#
# MoE
# =
# 𝑡
# ∗
# ⋅
# (
# 𝑠
# 𝑛
# )
# MoE=t
# ∗
#  ⋅(
# n
# ​
#
# s
# ​
#  )
# (depending on whether you're using a Z or T distribution)
#
# Where:
#
# 𝑧
# ∗
# z
# ∗
#   or
# 𝑡
# ∗
# t
# ∗
#  : critical value for the confidence level
#
# 𝜎
# σ or
# 𝑠
# s: population or sample standard deviation
#
# 𝑛
# n: sample size
#
# **How It Affects the Confidence Interval**
#
# The confidence interval is:
#
# CI
# =
# Sample Estimate
# ±
# Margin of Error
#
#    **CI=Sample Estimate±Margin of Error**
#
# So:
#
# * **Larger margin of error → Wider confidence interval** → Less precision
#
# * **Smaller margin of error → Narrower confidence interval** → More precision

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics , and what is its significance?
#
# Ans. At its core, **Bayes’ Theorem** lets you **update your beliefs** (probabilities) about an event based on **new evidence.**
#
# **Formula:**
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) = **Posterior probability:** the probability of A given B (after seeing evidence B)
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) = **Likelihood:** how likely B is, assuming A is true
#
# 𝑃
# (
# 𝐴
# )
# P(A) = **Prior probability:** what you believed about A before seeing B
#
# 𝑃
# (
# 𝐵
# )
# P(B) = Marginal probability: the total probability of B occurring
#
# **Why It’s Significant in Statistics**
#
# 1. **It Flips the Conditional**
# Bayes’ Theorem allows you to reverse conditional probabilities. For example:
#
# You know the probability of testing positive given someone has a disease.
#
# 2. **Foundational to Bayesian Inference**
# In Bayesian statistics, you continuously update your beliefs as new data comes in.
#
# Prior → what you believe before seeing the data
#
# Likelihood → how well the data fits your model
#
# Posterior → your updated belief after seeing the data
#
# This contrasts with frequentist statistics, where parameters are fixed and don't update with new data.
#
# 3. **Useful in Real-Life Decision Making**
# Bayes' Theorem is everywhere:
#
# Medical diagnostics: Interpreting test results
#
# Spam filters: Classifying emails based on past patterns
#
# Machine learning: In models like Naive Bayes classifiers
#
# Risk assessment: Updating probabilities in finance, insurance, etc.

# %% [markdown]
# 17. What is the Chi-square distribution , and when is it used?
#
# Ans. The Chi-square distribution is a **right-skewed probability distr**ibution that's used mainly in **hypothesis testing** involving **categorical data.**
#
# It’s based on the **sum of the squares of standard normal variables.** In other words, if you square several values that each follow a standard normal distribution (mean = 0, SD = 1) and add them up, that total follows a **Chi-square distribution.**
#
# 𝜒
# 2
# =
# 𝑍
# 1
# 2
# +
# 𝑍
# 2
# 2
# +
# ⋯
# +
# 𝑍
# 𝑘
# 2
# χ
# 2
#  =Z
# 1
# 2
# ​
#  +Z
# 2
# 2
# ​
#  +⋯+Z
# k
# 2
# ​
#
# Where
# 𝑍
# 𝑖
# Z
# i
# ​
#   are standard normal variables and
# 𝑘
# k is the **degrees of freedom (df).**
#
# **When Is It Used?**
#
# The Chi-square distribution is used in several types of statistical tests, mostly with categorical data:
#
# 1. **Chi-Square Test for Goodness of Fit**
#
# * **Purpose:** Tests if a sample distribution matches an expected (theoretical) distribution.
#
# **Example:** Is a die fair? Expected frequency = same for all faces. Chi-square can test this.
#
# 2. **Chi-Square Test for Independence (Contingency Tables)**
#
# * **Purpose:** Tests if two categorical variables are independent.
#
# * **Example:** Is there a relationship between gender and voting preference?
#
# You'd collect data in a 2-way table (like a survey) and compare observed vs. expected frequencies.
#
# Formula:
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
# Where:
#
# * 𝑂
# O = observed frequency
#
# * 𝐸
# E = expected frequency
#
# 3. **Chi-Square Test for Homogeneity**
#
# * Similar to the independence test but compares distributions of a categorical variable across different **populations or groups.**
#
# * Example: Are customer preferences for a product the same across three regions?

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how it is applied?
#
# Ans. It’s a hypothesis test that compares the observed frequencies in each category to the expected frequencies under a specific theoretical distribution.
#
# ** When to Use It:**
#
# You have one categorical variable with two or more categories.
#
# You want to test whether the distribution of your data matches a specific expectation.
#
# **Example Scenario:**
#
# You roll a die 60 times and get the following results:
#
# Face	Observed
# 1	5
# 2	8
# 3	9
# 4	12
# 5	11
# 6	15
# You want to test if the die is fair—i.e., each face should come up equally often.
#
# **Steps to Apply the Test:**
#
# **Step 1: Define Hypotheses**
# Null Hypothesis (H₀): The observed distribution fits the expected distribution (e.g., the die is fair).
#
# Alternative Hypothesis (H₁): The observed distribution does not fit the expected distribution.
#
# **Step 2: Calculate Expected Frequencies**
#
# If the die is fair, and you roll it 60 times:
#
# 𝐸
# =
# 60
# 6
# =
# 10
#  per face
# E=
# 6
# 60
# ​
#  =10 per face
# **Step 3: Use the Chi-Square Test Statistic**
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
# Where:
#
# 𝑂
# O = observed frequency
#
# 𝐸
# E = expected frequency
#
# Using the data:
#
# 𝜒
# 2
# =
# (
# 5
# −
# 10
# )
# 2
# 10
# +
# (
# 8
# −
# 10
# )
# 2
# 10
# +
# (
# 9
# −
# 10
# )
# 2
# 10
# +
# (
# 12
# −
# 10
# )
# 2
# 10
# +
# (
# 11
# −
# 10
# )
# 2
# 10
# +
# (
# 15
# −
# 10
# )
# 2
# 10
# χ
# 2
#  =
# 10
# (5−10)
# 2
#
# ​
#  +
# 10
# (8−10)
# 2
#
# ​
#  +
# 10
# (9−10)
# 2
#
# ​
#  +
# 10
# (12−10)
# 2
#
# ​
#  +
# 10
# (11−10)
# 2
#
# ​
#  +
# 10
# (15−10)
# 2
#
# ​
#
# =
# 25
# 10
# +
# 4
# 10
# +
# 1
# 10
# +
# 4
# 10
# +
# 1
# 10
# +
# 25
# 10
# =
# 6.0
# =
# 10
# 25
# ​
#  +
# 10
# 4
# ​
#  +
# 10
# 1
# ​
#  +
# 10
# 4
# ​
#  +
# 10
# 1
# ​
#  +
# 10
# 25
# ​
#  =6.0
# **Step 4: Find the Critical Value or P-value**
#
# Degrees of Freedom = number of categories - 1 = 6 - 1 = 5
#
# Significance level (α) = usually 0.05
#
# From the chi-square table, critical value at df = 5, α = 0.05 is 11.07
#
# **Step 5: Make a Decision**
#
# Since your calculated χ² = 6.0 < 11.07, you fail to reject H₀.
#
# This means: There’s no strong evidence that the die is unfair.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# Ans. It’s defined as the ratio of two scaled chi-squared distributions:
#
# 𝐹
# =
# (
# 𝑋
# 1
# /
# 𝑑
# 1
# )
# (
# 𝑋
# 2
# /
# 𝑑
# 2
# )
# F=
# (X
# 2
# ​
#  /d
# 2
# ​
#  )
# (X
# 1
# ​
#  /d
# 1
# ​
#  )
# ​
#
# where:
#
# 𝑋
# 1
# ∼
# 𝜒
# 2
# (
# 𝑑
# 1
# )
# X
# 1
# ​
#  ∼χ
# 2
#  (d
# 1
# ​
#  )
#
# 𝑋
# 2
# ∼
# 𝜒
# 2
# (
# 𝑑
# 2
# )
# X
# 2
# ​
#  ∼χ
# 2
#  (d
# 2
# ​
#  )
#
# 𝑑
# 1
# d
# 1
# ​
#   and
# 𝑑
# 2
# d
# 2
# ​
#   are the degrees of freedom for the numerator and denominator respectively.
#
# It's right-skewed, and its shape depends on the degrees of freedom.
# **When is it used in hypothesis testing?**
#
# 1. **Comparing Variances (F-test for equality of variances):**
#
# Used to test if two populations have equal variances.
#
# * 1Hypotheses:
#
# 𝐻
# 0
# :
# 𝜎
# 1
# 2
# =
# 𝜎
# 2
# 2
# vs.
# 𝐻
# 𝑎
# :
# 𝜎
# 1
# 2
# ≠
# 𝜎
# 2
# 2
# H
# 0
# ​
#  :σ
# 1
# 2
# ​
#  =σ
# 2
# 2
# ​
#  vs.H
# a
# ​
#  :σ
# 1
# 2
# ​
#
# 
# =σ
# 2
# 2
# ​
#
# * You compute the ratio of sample variances and compare it to the F-distribution.
#
# 2. **ANOVA (Analysis of Variance):**
#
# * Used to test whether the means of three or more groups are equal.
#
# * Hypotheses:
#
# 𝐻
# 0
# :
# 𝜇
# 1
# =
# 𝜇
# 2
# =
# …
# =
# 𝜇
# 𝑘
# vs.
# 𝐻
# 𝑎
# :
# At least one mean is different
# H
# 0
# ​
#  :μ
# 1
# ​
#  =μ
# 2
# ​
#  =…=μ
# k
# ​
#  vs.H
# a
# ​
#  :At least one mean is different
# * The test statistic is an F-ratio: variance between groups divided by variance within groups.
#
# 3. **Regression Analysis:**
#
# * The F-test is used to test the overall significance of a regression model (i.e., if at least one predictor variable has a non-zero coefficient).

# %% [markdown]
# 20. What is an ANOVA Test, and what are its assumptions.?
#
# Ans. ANOVA stands for **Analysis of Variance**. It's a statistical method used to **compare the means of three or more groups** to determine if at least one of them is statistically significantly different from the others.
#
# * It doesn't tell you which groups are different—just that **at least one group mean is not equal.**
#
# * If the ANOVA result is significant, you can follow up with **post-hoc tests** (like Tukey’s HSD) to find out where the differences lie.
#
# **Assumptions of ANOVA**
#
# 1. **Independence:**
#
# * Observations are independent of each other.
#
# * Usually ensured by random sampling or experimental design.
#
# 2. **Normality:**
#
# * The data in each group should be roughly normally distributed.
#
# * ANOVA is robust to mild violations, especially with large sample sizes.
#
# 3. **Homogeneity of variances (homoscedasticity):**
#
# * All groups should have similar variances.
#
# * Can be tested with Levene’s test or Bartlett’s test.

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#
#  There are several types of ANOVA tests, each designed for different experimental setups or research questions. Here's a breakdown of the most common ones:
#
# 1. **One-Way ANOVA (Single-Factor ANOVA)**
#
# * Purpose: Compares the means of three or more independent groups based on one factor (independent variable).
#
# * Example: Comparing test scores across 3 different teaching methods.
#
# * Design: One categorical independent variable (with ≥3 levels), one continuous dependent variable.
#
# 2. **Two-Way ANOVA (Factorial ANOVA)**
#
# * Purpose: Compares the means across groups defined by two independent variables (factors).
#
# * It can also test for interaction effects between the two factors.
#
# * Example: Studying the effect of teaching method and gender on test scores.
#
# **Variants:**
#
# * Two-Way ANOVA without replication: One observation per combination of factor levels.
#
# * Two-Way ANOVA with replication: Multiple observations per combination—more common and allows for interaction analysis.
#
# 3. **Repeated Measures ANOVA**
#
# * Purpose: Used when the same subjects are measured multiple times (e.g., over time or under different conditions).
#
# * Example: Measuring blood pressure of patients before, during, and after treatment.
#
# * Think of it as the ANOVA version of a paired t-test for more than two time points.
#
# 4. **MANOVA (Multivariate Analysis of Variance)**
#
# * Purpose: Like ANOVA, but with multiple dependent variables.
#
# * Example: Analyzing how different teaching styles affect both math and reading scores.
#
# 5. **ANCOVA (Analysis of Covariance)**
#
# * Purpose: ANOVA + controlling for a continuous covariate (e.g., age, IQ).
#
# * Adjusts the dependent variable by removing variability explained by the covariate.
#
# * Example: Comparing test scores across teaching methods while controlling for students’ prior GPA.

# %% [markdown]
# 22. What is the F-test and how does it relate to hypothesis testing?
#
# Ans. The **F-test** is a statistical test that uses the **F-distribution to compare two variances or multiple group means**. It’s used in various contexts, most notably in:
#
# * Comparing two population variances
#
# * Analysis of Variance (ANOVA)
#
# * Regression analysis (overall model significance)
#
# **General Idea in Hypothesis Testing:**
#
# The F-test checks whether the **variability between groups** is significantly greater than the **variability within groups.**
#
# **F-statistic Formula (general form):**
#
# 𝐹
# =
# Variance between groups
# Variance within groups
# F=
# Variance within groups
# Variance between groups
# ​
#
# If the null hypothesis is true (e.g., group means are equal or variances are equal), then this ratio should be close to 1. If it's much larger, that suggests **significant differences.**

# %% [markdown]
# ##Practical Questions

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

# === Input Data ===
population_mean = 100      # Known population mean (μ)
population_std = 15        # Known population standard deviation (σ)
sample = [102, 98, 105, 100, 99, 101, 97, 103, 100, 104]  # Sample data

# === Calculations ===
sample_mean = np.mean(sample)
sample_size = len(sample)
standard_error = population_std / np.sqrt(sample_size)

# Z-test statistic
z_score = (sample_mean - population_mean) / standard_error

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# === Output ===
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-Score = {z_score:.3f}")
print(f"P-Value = {p_value:.4f}")

# === Interpretation ===
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")
# Out:
# Sample Mean = 100.90
# Z-Score = 0.190
# P-Value = 0.8495
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy import stats

# === Step 1: Simulate sample data ===
np.random.seed(42)  # For reproducibility

# Simulate a sample of 30 students' test scores, normally distributed
sample = np.random.normal(loc=72, scale=10, size=30)  # mean=72, std=10

# === Step 2: Define population mean to test against ===
population_mean = 75  # Hypothesized population mean (e.g. expected test score)

# === Step 3: Perform one-sample t-test ===
t_stat, p_value = stats.ttest_1samp(sample, population_mean)

# === Step 4: Print results ===
print(f"Sample Mean: {np.mean(sample):.2f}")
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# === Step 5: Interpret the result ===
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Sample Mean: 70.12
# T-Statistic: -2.9707
# P-Value: 0.0059
# Reject the null hypothesis: The sample mean is significantly different from the population mean.

# %% [markdown]
# 3. Implement a one-sample Z-tets using Python to compare and the sample mean with the popultaion mean.

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std):
    sample_mean = np.mean(sample)
    n = len(sample)
    standard_error = population_std / np.sqrt(n)

    # Calculate Z-score
    z_score = (sample_mean - population_mean) / standard_error

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_score)))

    # Output results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-Score: {z_score:.4f}")
    print(f"P-Value: {p_value:.4f}")

    # Interpretation
    alpha = 0.05
    if p_value < alpha:
        print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference from the population mean.")

# === Example ===
# Simulate a sample
np.random.seed(1)
sample_data = np.random.normal(loc=102, scale=15, size=40)

# Known population parameters
pop_mean = 100
pop_std = 15

# Run Z-test
one_sample_z_test(sample_data, pop_mean, pop_std)
# Out:
# Sample Mean: 100.66
# Z-Score: 0.2766
# P-Value: 0.7821
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# === Step 1: Sample and Population Info ===
np.random.seed(42)
sample = np.random.normal(loc=102, scale=15, size=40)  # Sample data

population_mean = 100
population_std = 15
alpha = 0.05  # significance level (for two-tailed test, alpha/2 on each side)

# === Step 2: Perform Z-Test ===
sample_mean = np.mean(sample)
n = len(sample)
standard_error = population_std / np.sqrt(n)

z_score = (sample_mean - population_mean) / standard_error
p_value = 2 * (1 - norm.cdf(abs(z_score)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Score: {z_score:.4f}")
print(f"P-Value: {p_value:.4f}")

# === Step 3: Critical Z-values for decision region ===
z_critical = norm.ppf(1 - alpha/2)  # e.g., ±1.96 for alpha=0.05
z_left = -z_critical
z_right = z_critical

# === Step 4: Plotting the Standard Normal Curve ===
# Out:
# Sample Mean: 98.72
# Z-Score: -0.5395
# P-Value: 0.5895

# %% [markdown]
# 5.  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0=100, mu1=105, sigma=15, n=30, alpha=0.05):
    """
    Visualizes Type I and Type II errors in hypothesis testing.

    mu0: Null hypothesis mean
    mu1: True mean (alternative hypothesis)
    sigma: Population standard deviation
    n: Sample size
    alpha: Significance level
    """
    se = sigma / np.sqrt(n)  # Standard error

    # Critical value for two-tailed test
    z_crit = norm.ppf(1 - alpha / 2)
    x_crit_low = mu0 - z_crit * se
    x_crit_high = mu0 + z_crit * se

    # X range covering both distributions
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)

    # PDFs for null and alternative
    y_null = norm.pdf(x, mu0, se)
    y_alt = norm.pdf(x, mu1, se)

    # Plot both distributions
    plt.figure(figsize=(12, 6))
    plt.plot(x, y_null, label='Null Hypothesis (H₀)', color='blue')
    plt.plot(x, y_alt, label='Alternative Hypothesis (H₁)', color='green')

    # Shade Type I Error region (under H₀ but rejected)
    plt.fill_between(x, y_null, where=(x < x_crit_low) | (x > x_crit_high), color='red', alpha=0.4, label='Type I Error (α)')

    # Shade Type II Error region (under H₁ but not rejected)
    plt.fill_between(x, y_alt, where=(x > x_crit_low) & (x < x_crit_high), color='orange', alpha=0.4, label='Type II Error (β)')

    plt.axvline(x_crit_low, color='black', linestyle='--', label=f'Critical Values: {x_crit_low:.2f}, {x_crit_high:.2f}')
    plt.axvline(x_crit_high, color='black', linestyle='--')

    plt.title("Type I and Type II Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Calculate beta (Type II error) using CDF of H1 at critical values
    beta = norm.cdf(x_crit_high, mu1, se) - norm.cdf(x_crit_low, mu1, se)
    power = 1 - beta

    print(f"Type I Error (α): {alpha:.2f}")
    print(f"Type II Error (β): {beta:.4f}")
    print(f"Power of the Test: {power:.4f}")

# === Example Usage ===
visualize_type1_type2_errors(mu0=100, mu1=105, sigma=15, n=30, alpha=0.05)
# Out:
# Type I Error (α): 0.05
# Type II Error (β): 0.5533
# Power of the Test: 0.4467

# %% [markdown]
# 6. Write a Python program to perform an independant T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# === Step 1: Simulate data for two independent groups ===
np.random.seed(42)

# Group A: Mean = 70, std = 10, n = 30
group_a = np.random.normal(loc=70, scale=10, size=30)

# Group B: Mean = 75, std = 12, n = 30
group_b = np.random.normal(loc=75, scale=12, size=30)

# === Step 2: Perform Independent T-Test (Welch’s t-test by default) ===
t_stat, p_value = ttest_ind(group_a, group_b, equal_var=False)

# === Step 3: Print Results ===
print(f"Group A Mean: {np.mean(group_a):.2f}")
print(f"Group B Mean: {np.mean(group_b):.2f}")
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# === Step 4: Interpret the Result ===
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# Group A Mean: 68.12
# Group B Mean: 73.55
# T-Statistic: -2.0720
# P-Value: 0.0429
# Reject the null hypothesis: There is a significant difference between the two groups.

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# === Step 1: Simulate Paired Data ===
np.random.seed(42)
n = 20
before = np.random.normal(loc=70, scale=8, size=n)
after = before + np.random.normal(loc=2, scale=5, size=n)  # improvement by ~2 points

# === Step 2: Perform Paired Sample T-Test ===
t_stat, p_value = ttest_rel(before, after)

# === Step 3: Display Results ===
print(f"Mean (Before): {np.mean(before):.2f}")
print(f"Mean (After): {np.mean(after):.2f}")
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# === Step 4: Interpretation ===
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There's a significant difference between before and after.")
else:
    print("Fail to reject the null hypothesis: No significant difference between before and after.")

# === Step 5: Visualization ===
plt.figure(figsize=(10, 6))
plt.title("Paired Sample T-Test: Before vs After")
plt.ylabel("Score")

# Plot individual lines connecting paired scores
for i in range(n):
    plt.plot(['Before', 'After'], [before[i], after[i]], marker='o', color='gray', alpha=0.6)

# Plot average bars
plt.bar(['Before', 'After'], [np.mean(before), np.mean(after)],
        color=['skyblue', 'lightgreen'], alpha=0.7, label='Mean')

plt.grid(axis='y')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mean (Before): 68.63
# Mean (After): 69.30
# T-Statistic: -0.6192
# P-Value: 0.5432
# Fail to reject the null hypothesis: No significant difference between before and after.

# %% [markdown]
# 8.  Simulate data and perform both Z-test and T-test, then compare the results using Python

# %%
import numpy as np
from scipy.stats import norm, t

# === Step 1: Simulate sample data ===
np.random.seed(42)
sample = np.random.normal(loc=102, scale=15, size=30)  # true mean = 102
population_mean = 100
population_std = 15  # known (for Z-test)

# === Step 2: Z-Test ===
sample_mean = np.mean(sample)
n = len(sample)
se_z = population_std / np.sqrt(n)
z_score = (sample_mean - population_mean) / se_z
p_value_z = 2 * (1 - norm.cdf(abs(z_score)))

# === Step 3: T-Test ===
sample_std = np.std(sample, ddof=1)
se_t = sample_std / np.sqrt(n)
t_score = (sample_mean - population_mean) / se_t
df = n - 1
p_value_t = 2 * (1 - t.cdf(abs(t_score), df))

# === Step 4: Print Results ===
print("Z-Test Results")
print(f"Z-Score: {z_score:.4f}")
print(f"P-Value: {p_value_z:.4f}\n")

print("T-Test Results")
print(f"T-Score: {t_score:.4f}")
print(f"P-Value: {p_value_t:.4f}\n")

# === Step 5: Compare Results ===
if p_value_z < 0.05:
    print("Z-Test: Reject null hypothesis")
else:
    print("Z-Test: Fail to reject null hypothesis")

if p_value_t < 0.05:
    print("T-Test: Reject null hypothesis")
else:
    print("T-Test: Fail to reject null hypothesis")
# Out:
# Z-Test Results
# Z-Score: -0.3002
# P-Value: 0.7640
#
# T-Test Results
# T-Score: -0.3336
# P-Value: 0.7411
#
# Z-Test: Fail to reject null hypothesis
# T-Test: Fail to reject null hypothesis

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for the mean of a sample.

    Parameters:
        data (array-like): Sample data
        confidence (float): Confidence level (e.g. 0.95 for 95%)

    Returns:
        (mean, lower_bound, upper_bound)
    """
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # Standard Error
    df = n - 1  # degrees of freedom
    t_crit = t.ppf((1 + confidence) / 2, df)  # critical t-value

    margin_of_error = t_crit * std_err
    lower = mean - margin_of_error
    upper = mean + margin_of_error

    return mean, lower, upper

# === Example Usage ===
np.random.seed(42)
sample_data = np.random.normal(loc=75, scale=10, size=30)

mean, ci_lower, ci_upper = confidence_interval(sample_data, confidence=0.95)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: [{ci_lower:.2f}, {ci_upper:.2f}]")
# Out:
# Sample Mean: 73.12
# 95% Confidence Interval: [69.76, 76.48]

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a sample mean at a given confidence level.

    Parameters:
        data (array-like): Sample data
        confidence (float): Confidence level (default is 0.95 for 95%)

    Returns:
        margin_of_error (float)
    """
    n = len(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    std_error = sample_std / np.sqrt(n)

    df = n - 1  # Degrees of freedom
    t_critical = t.ppf((1 + confidence) / 2, df)  # Critical t-value

    margin_of_error = t_critical * std_error
    return margin_of_error

# === Example Usage ===
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=8, size=25)

moe = calculate_margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error at 95% confidence: ±{moe:.2f}")
# Out:
# Margin of Error at 95% confidence: ±3.16

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
def bayesian_inference(prior, likelihood, marginal_likelihood):
    """
    Calculate the posterior probability using Bayes' Theorem.

    Parameters:
        prior (float): Prior probability P(H), the initial belief about the hypothesis.
        likelihood (float): Likelihood P(D | H), the probability of observing the data given the hypothesis.
        marginal_likelihood (float): P(D), the total probability of the data (which normalizes the result).

    Returns:
        float: Posterior probability P(H | D)
    """
    # Apply Bayes' Theorem: P(H | D) = (P(D | H) * P(H)) / P(D)
    posterior = (likelihood * prior) / marginal_likelihood
    return posterior

# === Example: Medical Test for Disease ===
# 1. Prior probability (P(H)): Probability of having the disease (1% of the population).
prior = 0.01

# 2. Likelihood (P(D | H)): Probability of testing positive given you have the disease (True positive rate).
likelihood = 0.99

# 3. Marginal likelihood (P(D)): Total probability of testing positive.
#    This can be calculated as: P(D) = P(D | H) * P(H) + P(D | ~H) * P(~H)
#    P(D | ~H) is the probability of testing positive when you don't have the disease (False positive rate).
false_positive_rate = 0.05
non_disease_prob = 1 - prior  # Probability of not having the disease

marginal_likelihood = (likelihood * prior) + (false_positive_rate * non_disease_prob)

# 4. Calculate the Posterior Probability P(H | D) using Bayes' Theorem
posterior = bayesian_inference(prior, likelihood, marginal_likelihood)

# Output the result
print(f"Posterior Probability (P(H | D)): {posterior:.4f}")
# Out:
# Posterior Probability (P(H | D)): 0.1667

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# === Step 1: Create a Contingency Table ===
# Example: Examining the relationship between two categorical variables: Gender and Preference for a type of Product.
# 3 categories for Product Preference (A, B, C), and 2 categories for Gender (Male, Female)
data = {'Product A': [30, 10],  # Male = 30, Female = 10
        'Product B': [20, 30],  # Male = 20, Female = 30
        'Product C': [10, 20]}  # Male = 10, Female = 20

# Convert the dictionary to a pandas DataFrame (for easier handling)
df = pd.DataFrame(data, index=['Male', 'Female'])

print("Contingency Table (Observed Frequencies):")
print(df)

# === Step 2: Perform Chi-square Test for Independence ===
chi2_stat, p_value, dof, expected = chi2_contingency(df)

# === Step 3: Display Results ===
print("\nChi-Square Test Results:")
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-Value: {p_value:.4f}")
print("\nExpected Frequencies:")
print(expected)

# === Step 4: Interpret the Results ===
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: The two variables are dependent (there is an association between them).")
else:
    print("\nFail to reject the null hypothesis: The two variables are independent (no association between them).")
# Out:
# Contingency Table (Observed Frequencies):
#         Product A  Product B  Product C
# Male           30         20         10
# Female         10         30         20
#
# Chi-Square Test Results:
# Chi-Square Statistic: 15.3333
# Degrees of Freedom: 2
# P-Value: 0.0005
#
# Expected Frequencies:
# [[20. 25. 15.]
#  [20. 25. 15.]]
#
# Reject the null hypothesis: The two variables are dependent (there is an association between them).

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np

def calculate_expected_frequencies(observed):
    """
    Calculate the expected frequencies for a Chi-square test based on the observed data.

    Parameters:
        observed (2D array-like): The contingency table with observed frequencies.

    Returns:
        expected (2D array-like): The contingency table with expected frequencies.
    """
    # Convert to a NumPy array for easy manipulation
    observed = np.array(observed)

    # Calculate the row totals, column totals, and grand total
    row_totals = np.sum(observed, axis=1, keepdims=True)  # Sum along rows
    column_totals = np.sum(observed, axis=0, keepdims=True)  # Sum along columns
    grand_total = np.sum(observed)

    # Calculate expected frequencies
    expected = (row_totals * column_totals) / grand_total

    return expected

# === Example: Observed Data ===
observed_data = [
    [30, 20, 10],  # Male preferences for Product A, B, C
    [10, 30, 20]   # Female preferences for Product A, B, C
]

# Calculate expected frequencies
expected_data = calculate_expected_frequencies(observed_data)

# Display observed and expected frequencies
print("Observed Frequencies:")
print(np.array(observed_data))

print("\nExpected Frequencies:")
print(expected_data)
# Out:
# Observed Frequencies:
# [[30 20 10]
#  [10 30 20]]
#
# Expected Frequencies:
# [[20. 25. 15.]
#  [20. 25. 15.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

# %%
import numpy as np
from scipy.stats import chisquare

# === Step 1: Observed Data ===
# Let's say the observed results of rolling a die 60 times:
observed_data = [10, 12, 9, 11, 8, 10]  # Observed counts for faces 1 to 6

# === Step 2: Expected Data ===
# If the die is fair, each face should appear approximately 10 times (60 rolls / 6 faces):
expected_data = [10] * 6  # Expected counts for a fair die (60 rolls, 6 faces)

# === Step 3: Perform the Chi-Square Goodness-of-Fit Test ===
chi2_stat, p_value = chisquare(observed_data, expected_data)

# === Step 4: Display the Results ===
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# === Step 5: Interpret the Results ===
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: The die is not fair (the distribution is not uniform).")
else:
    print("\nFail to reject the null hypothesis: The die is fair (the distribution is uniform).")
# Out:
# Chi-Square Statistic: 1.0000
# P-value: 0.9626
#
# Fail to reject the null hypothesis: The die is fair (the distribution is uniform).

# %% [markdown]
# 15.  Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Parameters
df = 5  # Degrees of freedom
size = 10000  # Sample size for simulation

# Simulate random data from a Chi-square distribution
data = np.random.chisquare(df, size)

# Create a range of values for plotting the theoretical distribution
x = np.linspace(0, np.max(data), 1000)

# Calculate the probability density function (PDF) of the Chi-square distribution
pdf = chi2.pdf(x, df)

# Plot the histogram of the simulated data
plt.hist(data, bins=50, density=True, alpha=0.6, color='g', label='Simulated Data')

# Plot the theoretical Chi-square distribution
plt.plot(x, pdf, 'r-', lw=2, label=f'Chi-square Distribution (df={df})')

# Adding labels and title
plt.title(f'Chi-Square Distribution (df={df})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 16. Implement a F-test using Python to compare the variances of two random smaples.

# %%
import numpy as np
import scipy.stats as stats

# Function to perform an F-test
def f_test(sample1, sample2):
    # Compute the sample variances
    var1 = np.var(sample1, ddof=1)  # sample variance for sample1
    var2 = np.var(sample2, ddof=1)  # sample variance for sample2

    # Ensure var1 is the larger variance (this is important for the F-distribution)
    if var1 < var2:
        var1, var2 = var2, var1

    # Compute the F-statistic (larger variance / smaller variance)
    f_statistic = var1 / var2

    # Get the degrees of freedom for both samples
    df1 = len(sample1) - 1  # degrees of freedom for sample1
    df2 = len(sample2) - 1  # degrees of freedom for sample2

    # Compute the p-value from the F-distribution
    p_value = 1 - stats.f.cdf(f_statistic, df1, df2)

    # Return the results
    return f_statistic, p_value, var1, var2, df1, df2

# Example usage
# Generate two random samples with different variances
np.random.seed(42)
sample1 = np.random.normal(loc=0, scale=1, size=100)  # Sample 1 with variance 1
sample2 = np.random.normal(loc=0, scale=2, size=100)  # Sample 2 with variance 4

# Perform the F-test
f_stat, p_value, var1, var2, df1, df2 = f_test(sample1, sample2)

# Display the results
print(f"Sample 1 Variance: {var1}")
print(f"Sample 2 Variance: {var2}")
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Interpretation of the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in variances.")
# Out:
# Sample 1 Variance: 3.6379379882429994
# Sample 2 Variance: 0.82476989363016
# F-statistic: 4.410852064726685
# P-value: 8.102407633714392e-13
# Reject the null hypothesis: The variances are significantly different.

# %% [markdown]
# 17.  Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results

# %%
import numpy as np
import scipy.stats as stats

# Function to perform one-way ANOVA
def anova_test(*groups):
    # Perform the ANOVA test using scipy's f_oneway function
    f_statistic, p_value = stats.f_oneway(*groups)

    # Return the results
    return f_statistic, p_value

# Example usage
# Generate random data for three different groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 with mean 50
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 with mean 55
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 with mean 60

# Perform the ANOVA test
f_stat, p_value = anova_test(group1, group2, group3)

# Display the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Interpretation of the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in group means.")
# Out:
# F-statistic: 12.20952551797281
# P-value: 2.1200748140507065e-05
# Reject the null hypothesis: At least one group mean is significantly different.

# %% [markdown]
# 18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Function to perform one-way ANOVA
def anova_test(*groups):
    # Perform the ANOVA test using scipy's f_oneway function
    f_statistic, p_value = stats.f_oneway(*groups)
    return f_statistic, p_value

# Simulating data for multiple groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 with mean 50
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 with mean 55
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 with mean 60

# Perform the ANOVA test
f_stat, p_value = anova_test(group1, group2, group3)

# Display the results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Interpretation of the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in group means.")

# Visualizing the results
plt.figure(figsize=(8, 6))

# Boxplot to visualize the distributions of the groups
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True)

# Plotting the means of each group
means = [np.mean(group1), np.mean(group2), np.mean(group3)]
plt.plot([1, 2, 3], means, color='red', marker='o', label='Group Means', linestyle='--')

# Adding titles and labels
plt.title("One-Way ANOVA - Group Comparisons")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.legend()

# Show the plot
plt.show()
# Out:
# F-statistic: 12.20952551797281
# P-value: 2.1200748140507065e-05
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-22-27c7a58ab74c>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True)

# %% [markdown]
# 19.  Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Function to check assumptions for ANOVA
def check_anova_assumptions(*groups):
    """
    Check the three main assumptions for ANOVA: Normality, Independence, and Equal Variance.

    Parameters:
    - *groups: Groups of data for the ANOVA.

    Returns:
    - Assumption check results for Normality, Equal Variance, and Independence.
    """
    # 1. Normality Check using Shapiro-Wilk test
    normality_results = {}
    for i, group in enumerate(groups):
        stat, p_value = stats.shapiro(group)
        normality_results[f"Group {i+1} Normality (Shapiro-Wilk test)"] = (stat, p_value)

        # Q-Q Plot for visual check
        plt.figure(figsize=(6, 4))
        stats.probplot(group, dist="norm", plot=plt)
        plt.title(f'Q-Q Plot for Group {i+1}')
        plt.show()

    # 2. Homogeneity of Variance Check using Levene's test
    stat, p_value = stats.levene(*groups)
    homogeneity_result = f"Levene's test for Homogeneity of Variance: p-value = {p_value}"

    # 3. Visual check for Equal Variance (Boxplot)
    plt.figure(figsize=(8, 6))
    plt.boxplot(groups, patch_artist=True)
    plt.title('Boxplot to Check Equal Variance')
    plt.xlabel('Groups')
    plt.ylabel('Values')
    plt.show()

    # Return assumption check results
    return normality_results, homogeneity_result

# Example usage:
# Generate random data for multiple groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 with mean 50
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 with mean 55
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 with mean 60

# Check assumptions for the ANOVA
normality_results, homogeneity_result = check_anova_assumptions(group1, group2, group3)

# Print results
print("\nNormality Test Results (Shapiro-Wilk):")
for group, result in normality_results.items():
    print(f"{group}: Test Statistic = {result[0]}, p-value = {result[1]}")

print("\n" + homogeneity_result)
# Out:
# Normality Test Results (Shapiro-Wilk):
# Group 1 Normality (Shapiro-Wilk test): Test Statistic = 0.9751383104692292, p-value = 0.686805494291708
# Group 2 Normality (Shapiro-Wilk test): Test Statistic = 0.9836958322604062, p-value = 0.9129582559088101
# Group 3 Normality (Shapiro-Wilk test): Test Statistic = 0.96284138318188, p-value = 0.36537361581254646
#
# Levene's test for Homogeneity of Variance: p-value = 0.8626638812717601

# %% [markdown]
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Step 1: Simulate data for two factors (Treatment and Time)
np.random.seed(42)

# Factor 1: Treatment (A and B)
treatment = np.array(['A', 'B'])
# Factor 2: Time (T1 and T2)
time = np.array(['T1', 'T2'])

# Create the data by combining all combinations of treatments and times
data = []

for t in treatment:
    for ti in time:
        # Simulate response variable for each combination of treatment and time
        if t == 'A' and ti == 'T1':
            values = np.random.normal(loc=50, scale=10, size=30)  # Mean = 50 for A-T1
        elif t == 'A' and ti == 'T2':
            values = np.random.normal(loc=55, scale=10, size=30)  # Mean = 55 for A-T2
        elif t == 'B' and ti == 'T1':
            values = np.random.normal(loc=60, scale=10, size=30)  # Mean = 60 for B-T1
        else:  # t == 'B' and ti == 'T2'
            values = np.random.normal(loc=65, scale=10, size=30)  # Mean = 65 for B-T2

        # Store the data
        for v in values:
            data.append([t, ti, v])

# Convert data to DataFrame
df = pd.DataFrame(data, columns=['Treatment', 'Time', 'Response'])

# Step 2: Perform Two-Way ANOVA
model = ols('Response ~ C(Treatment) * C(Time)', data=df).fit()  # C(Treatment) * C(Time) for interaction
anova_table = anova_lm(model, typ=2)  # Type 2 sum of squares

# Display the ANOVA table
print(anova_table)

# Step 3: Visualize the results

# Interaction plot
plt.figure(figsize=(8, 6))
sns.pointplot(x='Time', y='Response', hue='Treatment', data=df, markers=['o', 's'], linestyles=['-', '--'])
plt.title('Interaction Plot: Treatment vs Time')
plt.xlabel('Time')
plt.ylabel('Response')
plt.legend(title='Treatment')
plt.show()

# Boxplot to visualize the distributions for each group
plt.figure(figsize=(8, 6))
sns.boxplot(x='Time', y='Response', hue='Treatment', data=df, palette="Set2")
plt.title('Boxplot: Treatment and Time Interaction')
plt.xlabel('Time')
plt.ylabel('Response')
plt.show()
# Out:
#                             sum_sq     df          F        PR(>F)
# C(Treatment)           3974.204497    1.0  45.589457  6.098782e-10
# C(Time)                 801.631306    1.0   9.195786  2.993116e-03
# C(Treatment):C(Time)      7.518135    1.0   0.086243  7.695335e-01
# Residual              10112.156460  116.0        NaN           NaN

# %% [markdown]
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Function to visualize the F-distribution
def plot_f_distribution(df1, df2, x_range=None):
    """
    Visualizes the F-distribution for given degrees of freedom df1 (numerator) and df2 (denominator).

    Parameters:
    - df1: Degrees of freedom for the numerator
    - df2: Degrees of freedom for the denominator
    - x_range: Range of x-axis for plotting the distribution (optional)
    """
    # Set x-axis range if not provided
    if x_range is None:
        x_range = np.linspace(0, 5, 1000)

    # Calculate the F-distribution
    f_values = stats.f.pdf(x_range, df1, df2)

    # Plot the F-distribution
    plt.figure(figsize=(8, 6))
    plt.plot(x_range, f_values, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')
    plt.title(f'F-Distribution: df1={df1}, df2={df2}')
    plt.xlabel('F-value')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example use case: Visualizing F-distribution for different degrees of freedom
plot_f_distribution(df1=5, df2=10)
plot_f_distribution(df1=10, df2=20)
plot_f_distribution(df1=20, df2=30)

# %% [markdown]
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Simulate data for three groups
np.random.seed(42)

# Simulating data for three groups
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 (Mean = 50, SD = 10)
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 (Mean = 55, SD = 10)
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 (Mean = 60, SD = 10)

# Combine the data into a single DataFrame
df = pd.DataFrame({
    'Group': ['Group 1'] * len(group1) + ['Group 2'] * len(group2) + ['Group 3'] * len(group3),
    'Value': np.concatenate([group1, group2, group3])
})

# Step 2: Perform the One-Way ANOVA test
f_stat, p_value = stats.f_oneway(group1, group2, group3)

# Display the results of the ANOVA test
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Step 3: Visualize the results with a boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Value', data=df, palette="Set2")
plt.title('One-Way ANOVA: Comparison of Group Means')
plt.xlabel('Group')
plt.ylabel('Value')
plt.show()

# Interpretation of the result based on the p-value
if p_value < 0.05:
    print("The result is significant: There are differences between the group means.")
else:
    print("The result is not significant: There are no differences between the group means.")
# Out:
# F-statistic: 12.20952551797281
# P-value: 2.1200748140507065e-05
# <ipython-input-26-e60c353e6a7d>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df, palette="Set2")
# The result is significant: There are differences between the group means.

# %% [markdown]
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate means.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Simulate random data from a normal distribution
np.random.seed(42)  # For reproducibility

# Simulating data: 1000 samples from a normal distribution with mean = 50 and standard deviation = 10
sample_data = np.random.normal(loc=50, scale=10, size=1000)

# Step 2: Define the hypothesized population mean
hypothesized_mean = 50  # This is the mean we want to compare against

# Step 3: Perform a one-sample t-test
t_statistic, p_value = stats.ttest_1samp(sample_data, hypothesized_mean)

# Step 4: Print results
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Step 5: Interpret the results
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the hypothesized population mean.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the sample mean and the hypothesized population mean.")
# Out:
# T-statistic: 0.6243089585093229
# P-value: 0.5325672436623001
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the hypothesized population mean.

# %% [markdown]
# 24. Perform a hypothesis test for population variance using a Chi-squre distribution and interpret the results.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Simulate random data (sample) from a normal distribution
np.random.seed(42)

# Simulating a sample of size 30 with a population variance of 100 (standard deviation of 10)
sample_size = 30
population_variance = 100
sample_data = np.random.normal(loc=0, scale=np.sqrt(population_variance), size=sample_size)

# Step 2: Define the hypothesized population variance
hypothesized_variance = 100

# Step 3: Calculate sample variance
sample_variance = np.var(sample_data, ddof=1)

# Step 4: Calculate the Chi-square test statistic
chi_square_statistic = (sample_size - 1) * sample_variance / hypothesized_variance

# Step 5: Compute the p-value for the test statistic
# Since we're doing a two-tailed test, we need to calculate the area in both tails.
df = sample_size - 1  # Degrees of freedom

# For a two-tailed test, we need to calculate the p-value by looking at the probability of the test statistic
# being larger than the computed value on either side of the distribution.
p_value = 2 * min(stats.chi2.cdf(chi_square_statistic, df), 1 - stats.chi2.cdf(chi_square_statistic, df))

# Step 6: Print results
print(f"Sample Variance: {sample_variance}")
print(f"Chi-square Statistic: {chi_square_statistic}")
print(f"P-value: {p_value}")

# Step 7: Interpret the results
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis: The population variance is significantly different from the hypothesized value.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the population variance and the hypothesized value.")
# Out:
# Sample Variance: 81.00115693656518
# Chi-square Statistic: 23.490335511603902
# P-value: 0.49271816451627504
# Fail to reject the null hypothesis: There is no significant difference between the population variance and the hypothesized value.

# %% [markdown]
# 25.  Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

# %%
import numpy as np
import scipy.stats as stats

# Function to perform Z-test for comparing proportions
def z_test_proportions(x1, n1, x2, n2, alpha=0.05):
    # Step 1: Calculate the proportions
    p1 = x1 / n1
    p2 = x2 / n2

    # Step 2: Calculate the pooled proportion
    p = (x1 + x2) / (n1 + n2)

    # Step 3: Calculate the standard error (SE) of the difference in proportions
    se = np.sqrt(p * (1 - p) * (1 / n1 + 1 / n2))

    # Step 4: Calculate the Z-test statistic
    z = (p1 - p2) / se

    # Step 5: Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z)))

    # Step 6: Output the results
    print(f"Z-statistic: {z}")
    print(f"P-value: {p_value}")

    # Step 7: Interpret the result
    if p_value < alpha:
        print("Reject the null hypothesis: The proportions are significantly different.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference between the proportions.")

# Example use case
# Group 1: 40 successes out of 100 trials
# Group 2: 50 successes out of 120 trials
x1 = 40  # Number of successes in group 1
n1 = 100  # Sample size of group 1
x2 = 50  # Number of successes in group 2
n2 = 120  # Sample size of group 2

z_test_proportions(x1, n1, x2, n2, alpha=0.05)
# Out:
# Z-statistic: -0.2503558720662702
# P-value: 0.8023121521186121
# Fail to reject the null hypothesis: There is no significant difference between the proportions.

# %% [markdown]
# 26.  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Simulate two datasets with different variances
np.random.seed(42)

# Dataset 1: Mean = 50, Standard deviation = 10, Sample size = 100
data1 = np.random.normal(loc=50, scale=10, size=100)

# Dataset 2: Mean = 50, Standard deviation = 20, Sample size = 100
data2 = np.random.normal(loc=50, scale=20, size=100)

# Step 2: Perform the F-test for comparing variances
var1 = np.var(data1, ddof=1)  # Sample variance for dataset 1
var2 = np.var(data2, ddof=1)  # Sample variance for dataset 2

# F-statistic: the ratio of variances
f_statistic = var1 / var2 if var1 > var2 else var2 / var1  # Ensure we use the larger variance as the numerator

# Degrees of freedom for each sample
df1 = len(data1) - 1
df2 = len(data2) - 1

# Step 3: Calculate the p-value using the F-distribution
p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

# Step 4: Print results
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

# Step 5: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The variances of the two datasets are significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the variances.")

# Step 6: Visualization (boxplot)
plt.figure(figsize=(8, 6))
sns.boxplot(data=[data1, data2], notch=True, vert=False, patch_artist=True)
plt.yticks([0, 1], ['Dataset 1', 'Dataset 2'])
plt.title('Boxplot for Variance Comparison between Two Datasets')
plt.xlabel('Values')
plt.show()
# Out:
# F-statistic: 4.410852064726684
# P-value: 1.6204815267428785e-12
# Reject the null hypothesis: The variances of the two datasets are significantly different.

# %% [markdown]
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Simulate observed data (e.g., outcomes of rolling a fair die 100 times)
np.random.seed(42)

# Simulate 100 rolls of a fair 6-sided die
observed_data = np.random.choice([1, 2, 3, 4, 5, 6], size=100, replace=True)

# Step 2: Calculate observed frequencies
observed_frequencies = [np.sum(observed_data == i) for i in range(1, 7)]

# Step 3: Define expected frequencies (assuming a fair die, the expected probability is 1/6 for each outcome)
expected_frequencies = [100 / 6] * 6  # For 100 rolls, the expected count for each face is 100/6

# Step 4: Perform the Chi-square goodness of fit test
chi_square_statistic, p_value = stats.chisquare(observed_frequencies, expected_frequencies)

# Step 5: Print results
print(f"Chi-square Statistic: {chi_square_statistic}")
print(f"P-value: {p_value}")

# Step 6: Interpretation
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis: The observed frequencies do not follow the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies follow the expected distribution.")

# Step 7: Visualize the observed and expected frequencies
categories = [1, 2, 3, 4, 5, 6]
plt.figure(figsize=(10, 6))
plt.bar(categories, observed_frequencies, width=0.4, label='Observed', color='blue', align='center')
plt.bar(categories, expected_frequencies, width=0.4, label='Expected', color='red', align='edge')
plt.xlabel('Die Face')
plt.ylabel('Frequency')
plt.title('Observed vs Expected Frequencies for a Fair Die (100 Rolls)')
plt.legend()
plt.show()
# Out:
# Chi-square Statistic: 8.359999999999998
# P-value: 0.13747966775950413
# Fail to reject the null hypothesis: The observed frequencies follow the expected distribution.
